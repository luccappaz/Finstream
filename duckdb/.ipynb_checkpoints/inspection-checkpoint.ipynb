# %%
from pypaimon import CatalogFactory

catalog_options = {
    'warehouse': 's3://warehouse/paimon',
    'fs.s3.endpoint': 'http://minio:9000',
    'fs.s3.accessKeyId': 'admin',
    'fs.s3.accessKeySecret': 'password',
    'fs.s3.region': 'us-east-1',  # MinIO ignora o valor, mas o campo precisa existir e não vazio
}

catalog = CatalogFactory.create(catalog_options)
table = catalog.get_table('default.credit_scored_paimon')

read_builder = table.new_read_builder()
splits = read_builder.new_scan().plan().splits()
table_read = read_builder.new_read()

# Retorna direto como Arrow Table, fácil de converter pra pandas
arrow_table = table_read.to_arrow(splits)
df = arrow_table.to_pandas()

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
df.head(10)
# Out:
#    id_cliente  target_real  predicao  \
# 0           3            1         2
# 1           0            1         2
# 2           1            2         2
# 3           2            1         2
# 4           4            2         2
# 5           5            1         2
# 6           6            1         2
# 7           7            1         2
# 8          11            2         2
# 9          12            1         1
#
#                                                                                                                                                justificativa
# 0                                                      Saldo negativo, histórico de créditos pagos até agora e valor alto em prazo longo indicam alto risco.
# 1                                                   Saldo negativo, conta crítica e proposto para consumo com prazo curto aumentam o risco de inadimplência.
# 2  Saldo baixo, histórico de créditos pagos até agora, valor alto em prazo longo e propósito relacionado ao consumo (Rádio/Televisão) indicam um alto risco.
# 3                                   Ausência de conta corrente, histórico de 'Conta crítica / Outros bancos' e valor alto em prazo longo indicam alto risco.
# 4                                                                           Saldo negativo, atrasos passados e valor alto em prazo longo indicam alto risco.
# 5                                                                                 Ausência de conta corrente e valor alto em prazo longo indicam alto risco.
# 6                                                    Ausência de conta corrente, histórico de créditos pagos e valor alto em prazo longo indicam alto risco.
# 7                    Saldo baixo, histórico de crédito sem problemas, prazo mediano e proposto para um carro usado não são suficientes para reduzir o risco.
# 8                                                      Saldo negativo, histórico de créditos pagos até agora e valor alto em prazo longo indicam alto risco.
# 9                                            Saldo baixo, histórico de créditos pagos até agora e propósito produtivo (rádio/televisão) indicam baixo risco.
